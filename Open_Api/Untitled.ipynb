# %%
import requests
from urllib.request import urlopen
from urllib import urlencode, quote_plus

url = 'http://apis.data.go.kr/1192000/OceansBeachSeawaterService/getOceansBeachSeawaterInfo'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : '08un1SDWwxvMxkCQwzES6WAgo9UiKywjZFnSVsV9wCudGxhUgtye%2FS0%2B1OG9CMiCk08Yncq1MwO%2B20FIBoO3eg%3D%3D',\
                                quote_plus('ServiceKey') : '-', quote_plus('pageNo') : '1',\
                                quote_plus('numOfRows') : '10', quote_plus('SIDO_NM') : '충남',\
                                quote_plus('RES_YEAR') : '2016', quote_plus('resultType') : 'xml' })

request = requestst(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-4424dba84e43> in <module>
#       1 import requests
#       2 from urllib.request import urlopen
# ----> 3 from urllib.request import urlencode, quote_plus
#       4
#       5 url = 'http://apis.data.go.kr/1192000/OceansBeachSeawaterService/getOceansBeachSeawaterInfo'
#
# ImportError: cannot import name 'urlencode' from 'urllib.request' (C:\Users\82106\Anaconda3\lib\urllib\request.py)

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request

response = requests.get("http://apis.data.go.kr/1192000/OceansBeachSeawaterService/getOceansBeachSeawaterInfo?serviceKey=08un1SDWwxvMxkCQwzES6WAgo9UiKywjZFnSVsV9wCudGxhUgtye%2FS0%2B1OG9CMiCk08Yncq1MwO%2B20FIBoO3eg%3D%3D&pageNo=3&numOfRows=10&SIDO_NM=%EC%B6%A9%EB%82%A8&RES_YEAR=2016&resultType=xml&")
source = response.text

s1 = BeautifulSoup(source, 'html.parser')


print(s1)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
# <header>
# <resultcode>00</resultcode>
# <resultmsg>NORMAL SERVIE</resultmsg>
# </header>
# <body>
# <items>
# <item>
# <num>21</num>
# <seawaterid>16608</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>03</resnum>
# <resloc>C</resloc>
# <res1>21</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-08-02 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>22</num>
# <seawaterid>16607</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>03</resnum>
# <resloc>B</resloc>
# <res1>31</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-08-02 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>23</num>
# <seawaterid>16604</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>02</resnum>
# <resloc>D</resloc>
# <res1>7</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-07-16 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>24</num>
# <seawaterid>16603</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>02</resnum>
# <resloc>C</resloc>
# <res1>3</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-07-16 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>25</num>
# <seawaterid>16602</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>02</resnum>
# <resloc>B</resloc>
# <res1>7</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-07-16 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>26</num>
# <seawaterid>16599</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>01</resnum>
# <resloc>D</resloc>
# <res1>29</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-06-23 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>27</num>
# <seawaterid>16598</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>01</resnum>
# <resloc>C</resloc>
# <res1>30</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-06-23 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>28</num>
# <seawaterid>16597</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>보령시</gugunnm>
# <stanm>대천</stanm>
# <resnum>01</resnum>
# <resloc>B</resloc>
# <res1>35</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-06-23 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.31045400</lat>
# <lon>126.51318200</lon>
# </item>
# <item>
# <num>29</num>
# <seawaterid>15142</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>태안군</gugunnm>
# <stanm>신두리</stanm>
# <resnum>02</resnum>
# <resloc>C</resloc>
# <res1>25</res1>
# <res2>10</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-08-04 00:00:00.0</resdate>
# <resknd>개장중</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.83741800</lat>
# <lon>126.18471900</lon>
# </item>
# <item>
# <num>30</num>
# <seawaterid>5392</seawaterid>
# <sidonm>충남</sidonm>
# <gugunnm>태안군</gugunnm>
# <stanm>구례포</stanm>
# <resnum>01</resnum>
# <resloc>A</resloc>
# <res1>6</res1>
# <res2>&lt;1</res2>
# <resyn>적합</resyn>
# <resyear>2016</resyear>
# <resdate>2016-09-02 00:00:00.0</resdate>
# <resknd>폐장후</resknd>
# <reslocdetail></reslocdetail>
# <lat>36.88690300</lat>
# <lon>126.19805600</lon>
# </item>
# </items>
# <numofrows>10</numofrows>
# <pageno>3</pageno>
# <totalcount>729</totalcount>
# </body>
# </response>
